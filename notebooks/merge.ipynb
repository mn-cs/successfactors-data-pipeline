# %%
import pandas as pd
import glob

# %%
splited_path = glob.glob("../data/interim/billionaires_*.csv")[0]
df = pd.read_csv(splited_path)
df.head(5)
# Out:
#    rank               id             name         source        country  \
# 0     1        elon-musk        Elon Musk  Tesla, SpaceX  United States
# 1     2    larry-ellison    Larry Ellison         Oracle  United States
# 2     3  mark-zuckerberg  Mark Zuckerberg       Facebook  United States
# 3     4       jeff-bezos       Jeff Bezos         Amazon  United States
# 4     5       larry-page       Larry Page         Google  United States
#
#   gender  age                                              image  \
# 0      M   54  https://specials-images.forbesimg.com/imageser...
# 1      M   81  https://specials-images.forbesimg.com/imageser...
# 2      M   41  https://specials-images.forbesimg.com/imageser...
# 3      M   61  https://specials-images.forbesimg.com/imageser...
# 4      M   52  https://specials-images.forbesimg.com/imageser...
#
#    current_worth  previous_worth
# 0          413.1           415.6
# 1          271.6           272.6
# 2          251.8           253.0
# ...

# %%
splited_path = glob.glob("../data/interim/trimmed*.csv")[0]
df = pd.read_csv(splited_path)
df.head()
# Out:
#    rank             name         source        country gender  age  \
# 0     1        Elon Musk  Tesla, SpaceX  United States      M   54
# 1     2    Larry Ellison         Oracle  United States      M   81
# 2     3  Mark Zuckerberg       Facebook  United States      M   41
# 3     4       Jeff Bezos         Amazon  United States      M   61
# 4     5       Larry Page         Google  United States      M   52
#
#    current_worth
# 0          413.1
# 1          271.6
# 2          251.8
# 3          237.6
# 4          177.1

# %%
date_of_birth_path = glob.glob("../data/interim/date_of_birth_*.csv")[0]
df_date_of_birth_path = pd.read_csv(date_of_birth_path)
df_date_of_birth_path.head()
# Out:
#         clean_name    year  month   day
# 0        Elon Musk  1971.0    6.0  28.0
# 1    Larry Ellison  1944.0    8.0  17.0
# 2  Mark Zuckerberg  1984.0    5.0  14.0
# 3       Jeff Bezos  1964.0    1.0  12.0
# 4       Larry Page  1973.0    3.0  26.0

# %%
splited_path = glob.glob("../data/interim/splited_edu_*.csv")[0]
df = pd.read_csv(splited_path)
df.head(5)
# Out:
#        forbes_name       clean_name  \
# 0        Elon Musk        Elon Musk
# 1    Larry Ellison    Larry Ellison
# 2  Mark Zuckerberg  Mark Zuckerberg
# 3       Jeff Bezos       Jeff Bezos
# 4       Larry Page       Larry Page
#
#                                            education  \
# 0             University of Pennsylvania ( BA , BS )
# 1  University of Illinois, Urbana-Champaign (no d...
# 2                   Harvard University (dropped out)
# 3                       Princeton University ( BSE )
# 4  University of Michigan ( BSE ) Stanford Univer...
#
#                                university_1     degree_1  \
# 0                University of Pennsylvania      BA , BS
# 1  University of Illinois, Urbana-Champaign    no degree
# 2                        Harvard University  dropped out
# 3                      Princeton University          BSE
# 4                    University of Michigan          BSE
#
#             university_2   degree_2 university_3 degree_3
# ...

# %%
# "../data/interim/billionaires_*.csv": rank, name, source, country, gender, age, current_worth


# "../data/interim/trimmed*.csv": name
# "../data/interim/date_of_birth_*.csv": clean_name, year, month,  day
# "../data/interim/splited_edu_*.csv": clean_name, university_1, degree_1, university_2, degree_2, university_3, degree_3

# %%
# splited_path = glob.glob("../data/external/web_scraped/wiki_date_of_birth_*.csv")[0]
# df = pd.read_csv(splited_path)
# df = pd.read_csv(splited_path, dtype={"year": "Int64", "month": "Int64", "day": "Int64"})
# df.head()

# %%
merg = glob.glob("../data/interim/merged_dataset_*.csv")[0]
df_merg = pd.read_csv(merg, dtype={"year": "Int64", "month": "Int64", "day": "Int64"})
df_merg.head()
# Out:
#     rank                     name             source        country gender  \
# 0      1                Elon Musk      Tesla, SpaceX  United States      M
# 1      2            Larry Ellison             Oracle  United States      M
# 2      3          Mark Zuckerberg           Facebook  United States      M
# 3      4               Jeff Bezos             Amazon  United States      M
# 4      5               Larry Page             Google  United States      M
# ..   ...                      ...                ...            ...    ...
# 95    96        Gennady Timchenko           Oil, gas         Russia      M
# 96    97  Zheng Shuliang & family  Aluminum products          China      F
# 97    98              Steve Cohen        Hedge funds  United States      M
# 98    99     Vicky Safra & family            Banking         Brazil      F
# 99   100         Ernest Garcia II          Used cars  United States      M
#
#     age  current_worth  year  month   day  \
# ...
